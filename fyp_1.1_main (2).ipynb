# %%
# !pip install pickle-mixin
# Out:
# Collecting pickle-mixin
#   Downloading pickle-mixin-1.0.2.tar.gz (5.1 kB)
# Building wheels for collected packages: pickle-mixin
#   Building wheel for pickle-mixin (setup.py): started
#   Building wheel for pickle-mixin (setup.py): finished with status 'done'
#   Created wheel for pickle-mixin: filename=pickle_mixin-1.0.2-py3-none-any.whl size=6003 sha256=ea8e355c819e8a7d19f2efe43848e9b8bc9edc0e7a4d5446db4f0c1cb84dafa4
#   Stored in directory: c:\users\acer\appdata\local\pip\cache\wheels\2a\a4\6c\83bfbc3b94f1bb43d634b07a6a893fd437a45c58b29aea5142
# Successfully built pickle-mixin
# Installing collected packages: pickle-mixin
# Successfully installed pickle-mixin-1.0.2

# %%
# !pip install praat-parselmouth
# Out:
# Collecting praat-parselmouth
#   Using cached praat_parselmouth-0.4.0-cp38-cp38-win_amd64.whl (8.9 MB)
# Requirement already satisfied: numpy>=1.7.0 in c:\users\acer\.conda\envs\tensorflow\lib\site-packages (from praat-parselmouth) (1.20.2)
# Installing collected packages: praat-parselmouth
# Successfully installed praat-parselmouth-0.4.0

# %%
import parselmouth
from parselmouth.praat import call, run_file
import glob
import pandas as pd
import numpy as np
import scipy
from scipy.stats import binom
from scipy.stats import ks_2samp
from scipy.stats import ttest_ind
import os
import pickle
import matplotlib.pyplot as plt

# %%
p = r"C:/Users/Acer/FYP_1.1_pro"

# %%
def run_praat_expert(p):
    
    arrarOfData = []
#     E:\jupyter_project\FYP_1.1_pro\audio\copy_expert
    dir_lists = os.listdir('C:/Users/Acer/FYP_1.1_pro/audio/copy_expert/')
    for dir_list in dir_lists:
        file_list = os.listdir('C:/Users/Acer/FYP_1.1_pro/audio/copy_expert/' + dir_list)
        for audiofile in file_list:
            file_format = audiofile.split('.')[1]
#             print(file_format)
            if(file_format == "wav"):
                m = audiofile.split('.')[0]
                
                sound=p+"/"+"audio"+"/"+"copy_expert"+"/"+dir_list+"/"+m+".wav"
                sourcerun=p+"/"+"myprosody"+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
                path=p+"/"+"myprosodytest"+"/"+"expert"
#                 ppp =p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"+dir_list+"/"
                try:
                    objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
    #                 print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
                    z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
                    z2=z1.strip().split()
                    z3=int(z2[13]) # will be the integer number 10
                    z4=float(z2[14]) # will be the floating point number 8.3
                    db= binom.rvs(n=10,p=z4,size=10000)
                    a=np.array(db)
                    b=np.mean(a)*100/10
                    del z2[-1]
                    aaa = str(audiofile)
                    z2.append(format(b,'.2f'))
                    z2.append(aaa)
                    arrarOfData.append(z2)
    #                 print (dataset.T)
                except:
                    print ("Try again the sound of the audio was not clear")
    dff = pd.DataFrame(arrarOfData,columns=("number_of_syllables","number_of_pauses","rate_of_speech","articulation_rate","speaking_duration","original_duration","balance","f0_mean","f0_std","f0_median","f0_min","f0_max","f0_quantile25","f0_quan75","pronunciation_score_percentage","name_of_audio"))
#     print(arrarOfData)
    dff.to_csv('audio/metadata_new/expert_metadata.csv')
    print("done")

# %%
run_praat_expert(p)
# Out:
# done

# %%
def run_praat_train(p):
    
    arrarOfData = []
    dir_lists = os.listdir('C:/Users/Acer/FYP_1.1_pro/audio/copy_train/')
    for dir_list in dir_lists:
        file_list = os.listdir('C:/Users/Acer/FYP_1.1_pro/audio/copy_train/' + dir_list)
        for audiofile in file_list:
            file_format = audiofile.split('.')[1]
#             print(file_format)
            if(file_format == "wav"):
                m = audiofile.split('.')[0]
                
                sound=p+"/"+"audio"+"/"+"copy_train"+"/"+dir_list+"/"+m+".wav"
                sourcerun=p+"/"+"myprosody"+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
                path=p+"/"+"myprosodytest"+"/"+"train"
                
                try:
                    objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
    #                 print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
                    z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
                    z2=z1.strip().split()
                    z3=int(z2[13]) # will be the integer number 10
                    z4=float(z2[14]) # will be the floating point number 8.3
                    db= binom.rvs(n=10,p=z4,size=10000)
                    a=np.array(db)
                    b=np.mean(a)*100/10
                    del z2[-1]
                    aaa = str(audiofile)
                    z2.append(format(b,'.2f'))
                    z2.append(aaa)
                    arrarOfData.append(z2)
                except:
                    print ("Try again the sound of the audio was not clear")
    dff = pd.DataFrame(arrarOfData,columns=("number_of_syllables","number_of_pauses","rate_of_speech","articulation_rate","speaking_duration","original_duration","balance","f0_mean","f0_std","f0_median","f0_min","f0_max","f0_quantile25","f0_quan75","pronunciation_score_percentage","name_of_audio"))
#     print(arrarOfData)
    dff.to_csv('audio/metadata_new/train_metadata.csv')
    print("done")

# %%
run_praat_train(p)
# Out:
# done

# %%
## train data set file
train_metadata = pd.read_csv('audio/metadata_new/train_metadata.csv') 
train_metadata.head()
# Out:
#    Unnamed: 0  number_of_syllables  number_of_pauses  rate_of_speech  \
# 0           0                  133                10               3
# 1           1                  145                13               4
# 2           2                  126                21               3
# 3           3                  160                 7               4
# 4           4                  127                19               3
#
#    articulation_rate  speaking_duration  original_duration  balance  f0_mean  \
# 0                  4               31.6               39.5      0.8   233.24
# 1                  4               33.0               40.9      0.8   262.39
# 2                  5               27.5               45.4      0.6   246.01
# 3                  5               33.1               38.1      0.9   270.39
# 4                  4               33.9               50.3      0.7   235.25
#
#    f0_std  f0_median  f0_min  f0_max  f0_quantile25  f0_quan75  \
# 0   35.64      230.9      95     383            215        255
# 1   54.99      257.9      80     418            229        297
# 2   64.38      228.5      80     415            204        300
# 3   42.15      266.0      87     412            242        302
# 4   56.89      224.8      71     420            202        269
#
#    pronunciation_score_percentage  name_of_audio
# 0                           89.99  S100_P1_F.wav
# 1                          100.00   S13_P1_F.wav
# 2                           69.78   S15_P1_F.wav
# 3                           95.03    S1_P1_F.wav
# 4                           69.73    S2_P1_F.wav

# %%
# importing the module
import pandas as pd
  
# read specific columns of csv file using Pandas
df_student = pd.read_csv("audio/metadata_new/train_metadata.csv", usecols = ['name_of_audio','pronunciation_score_percentage'])
print(df_student)


df_student.to_csv('audio/metadata_new/train_metadata_needed.csv')
print("done")
# Out:
#      pronunciation_score_percentage  name_of_audio
# 0                             89.99  S100_P1_F.wav
# 1                            100.00   S13_P1_F.wav
# 2                             69.78   S15_P1_F.wav
# 3                             95.03    S1_P1_F.wav
# 4                             69.73    S2_P1_F.wav
# ..                              ...            ...
# 484                           94.95    S6_P9_F.wav
# 485                           69.84   S74_P9_F.wav
# 486                           85.04   S77_P9_F.wav
# 487                           85.06   S80_P9_F.wav
# 488                           85.12   S82_P9_F.wav
#
# [489 rows x 2 columns]
# done

# %%
## expert data set file
expert_metadata = pd.read_csv('audio/metadata_new/expert_metadata.csv') 
expert_metadata.head()
# Out:
#    Unnamed: 0  number_of_syllables  number_of_pauses  rate_of_speech  \
# 0           0                  139                11               3
# 1           1                  584                37               4
# 2           2                  223                15               4
# 3           3                  202                16               4
# 4           4                  148                 8               4
#
#    articulation_rate  speaking_duration  original_duration  balance  f0_mean  \
# 0                  5               30.8               43.6      0.7   227.95
# 1                  5              115.2              148.2      0.8   206.90
# 2                  5               45.5               57.2      0.8   231.78
# 3                  5               42.1               54.2      0.8   235.23
# 4                  5               28.4               36.6      0.8   200.50
#
#    f0_std  f0_median  f0_min  f0_max  f0_quantile25  f0_quan75  \
# 0   56.11      219.3      73     420            191        266
# 1   47.11      203.8      75     420            174        227
# 2   57.89      221.6      72     420            196        262
# 3   56.20      224.8      75     420            200        272
# 4   58.06      197.8      71     396            173        225
#
#    pronunciation_score_percentage name_of_audio
# 0                           85.00     E2_P1.wav
# 1                           95.07     E3_P1.wav
# 2                           95.05    E2_P10.wav
# 3                           95.06    E2_P11.wav
# 4                           95.05    E1_P12.wav

# %%
# importing the module
import pandas as pd
  
# read specific columns of csv file using Pandas
df_student = pd.read_csv("audio/metadata_new/expert_metadata.csv", usecols = ['name_of_audio','pronunciation_score_percentage'])
print(df_student)


df_student.to_csv('audio/metadata_new/expert_metadata_needed.csv')
print("done")
# Out:
#     pronunciation_score_percentage name_of_audio
# 0                            85.00     E2_P1.wav
# 1                            95.07     E3_P1.wav
# 2                            95.05    E2_P10.wav
# 3                            95.06    E2_P11.wav
# 4                            95.05    E1_P12.wav
# 5                            94.92    E2_P12.wav
# 6                            84.95    E2_P13.wav
# 7                            94.96     E3_P2.wav
# 8                            95.03     E2_P3.wav
# 9                            95.04     E3_P3.wav
# 10                           95.06     E1_P4.wav
# 11                           94.96     E2_P4.wav
# 12                           95.00     E3_P4.wav
# 13                           95.02     E1_P5.wav
# 14                           84.95     E2_P5.wav
# 15                           94.91     E1_P6.wav
# 16                           94.94     E1_P7.wav
# 17                          100.00     E1_P8.wav
# 18                           94.97     E2_P8.wav
# done

# %%
import os
import glob
import pandas as pd
#set working directory
os.chdir("C:/Users/Acer/FYP_1.1_pro/audio/metadata_new/final_metadata")

#find all csv files in the folder
#use glob pattern matching -> extension = 'csv'
#save result in list -> all_filenames
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
#print(all_filenames)

#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')
print("done")
combined_csv.head()
# Out:
# done
#    Unnamed: 0  pronunciation_score_percentage name_of_audio
# 0           0                           85.00     E2_P1.wav
# 1           1                           95.07     E3_P1.wav
# 2           2                           95.05    E2_P10.wav
# 3           3                           95.06    E2_P11.wav
# 4           4                           95.05    E1_P12.wav
